# %%
import pandas as pd

# %%
data = pd.read_csv("datasets/check-img.csv")
data.head()
# Out:
#     id                                              texto  \
# 0  213  Departamento de Justiça dos EUA divulgam ao mu...
# 1  855  China sugere ao Brasil a Lei que dá pena de mo...
# 2  983  Quem quer dar aula faz isso por gosto, e não p...
# 3   36  ONU prevê que toda a humanidade seja chipada a...
# 4  626  Santa Catarina Tem hoje a menor taxa de assass...
#
#                                                  URL  \
# 0  https://aosfatos.org/noticias/eua-nao-pediram-...
# 1  https://piaui.folha.uol.com.br/lupa/2018/12/11...
# 2  https://piaui.folha.uol.com.br/lupa/2018/09/03...
# 3  https://aosfatos.org/noticias/onu-nao-previu-i...
# 4  https://piaui.folha.uol.com.br/lupa/2019/05/23...
#
#                              Author     datePublished  \
# 0            https:www.aosfatos.org        08/11/2018
# 1  https:piaui.folha.uol.com.brlupa  11/12/2018 21:50
# 2  https:piaui.folha.uol.com.brlupa  03/09/2018 10:05
# 3            https:www.aosfatos.org        14/06/2019
# ...

# %%
data.isnull().sum()
# Out:
# id                 0
# texto              0
# URL                0
# Author             0
# datePublished      0
# title              0
# rotulo             0
# short url         38
# url               38
# imagem           349
# dtype: int64

# %%
df = data[data['imagem'].notna()]

# %%
df.head()
# Out:
#       id                                              texto  \
# 4    626  Santa Catarina Tem hoje a menor taxa de assass...
# 6    972  TSE entregou códigos de segurança das urnas el...
# 19    42  Portal Transparência mostra que gestão Bolsona...
# 22  1043  Bebê nasce com 18 kg e bate o recorde de maior...
# 23   831  O presidente eleito [Bolsonaro] e seu filho [E...
#
#                                                   URL  \
# 4   https://piaui.folha.uol.com.br/lupa/2019/05/23...
# 6   https://piaui.folha.uol.com.br/lupa/2018/09/18...
# 19  https://aosfatos.org/noticias/orcamento-da-edu...
# 22  https://checamos.afp.com/bebe-vista-nesta-foto...
# 23  https://piaui.folha.uol.com.br/lupa/2019/01/03...
#
#                               Author     datePublished  \
# 4   https:piaui.folha.uol.com.brlupa  23/05/2019 18:49
# 6   https:piaui.folha.uol.com.brlupa  18/09/2018 20:05
# 19            https:www.aosfatos.org        11/06/2019
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 251 entries, 4 to 595
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             251 non-null    int64
#  1   texto          251 non-null    object
#  2   URL            251 non-null    object
#  3   Author         251 non-null    object
#  4   datePublished  251 non-null    object
#  5   title          251 non-null    object
#  6   rotulo         251 non-null    object
#  7   short url      251 non-null    object
#  8   url            251 non-null    object
#  9   imagem         251 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 21.6+ KB

# %%
df.to_csv('datasets/dataset-img.csv', index=False)
